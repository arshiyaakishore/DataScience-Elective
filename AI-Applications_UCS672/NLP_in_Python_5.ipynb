# %% [markdown]
# <a href="https://colab.research.google.com/github/arshiyaakishore/DataScience-Elective/blob/main/AI-Applications_UCS672/NLP_in_Python_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Topic Modeling

# %% [markdown]
# ## Introduction

# %% [markdown]
# Another popular text analysis technique is called topic modeling. The ultimate goal of topic modeling is to find various topics that are present in your corpus. Each document in the corpus will be made up of at least one topic, if not multiple topics.
#
# In this notebook, we will be covering the steps on how to do **Latent Dirichlet Allocation (LDA)**, which is one of many topic modeling techniques. It was specifically designed for text data.
#
# To use a topic modeling technique, you need to provide (1) a document-term matrix and (2) the number of topics you would like the algorithm to pick up.
#
# Once the topic modeling technique is applied, your job as a human is to interpret the results and see if the mix of words in each topic make sense. If they don't make sense, you can try changing up the number of topics, the terms in the document-term matrix, model parameters, or even try a different model.

# %% [markdown]
# ***LDA looks at the document-term matrix and tries to figure out which words tend to appear together in documents. It assumes that each document is made up of a mix of topics, and each topic is made up of a mix of words. So, LDA tries to find those mixes that best explain the data.***

# %% [markdown]
# ## Topic Modeling - Attempt #1 (All Text)

# %%
#uncover the hidden thematic structure in a corpus of texts

# Let's read in our document-term matrix
import pandas as pd
import pickle

data = pd.read_pickle('dtm.pkl')
data
# Out:
#               aahetfield  aarp  ability  able  aboutand  aboutpetty  \
# BOB DYLAN              0     0        0     2         0           0
# MAC MILLER             0     0        0     0         1           0
# METALLICA              1     0        2     2         0           0
# MUDCRUTCH              0     0        0     0         0           1
# TOM PETTY              0     0        0     0         0           0
# TONY BENNETT           0     1        0     0         0           0
#
#               aboutrunnin  absolutely  abstract  abuse  ...  youplayboy  \
# BOB DYLAN               0           0         0      0  ...           0
# MAC MILLER              1           0         0      0  ...           0
# METALLICA               0           1         1      1  ...           1
# MUDCRUTCH               0           0         0      0  ...           0
# TOM PETTY               0           0         0      0  ...           0
# ...

# %%
# Import the necessary modules for LDA with gensim
# Terminal / Anaconda Navigator: conda install -c conda-forge gensim

#This module contains utility functions for converting data structures to and from NumPy matrices

from gensim import matutils, models
import scipy.sparse

# This module from the SciPy library provides support for sparse matrices,
#which are often used to represent large datasets efficiently, especially in the context of text data.
# import logging
# logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)

# %%
# One of the required inputs is a term-document matrix
tdm = data.transpose() #transpose of doc matrix hogya
tdm.head()
# Out:
#             BOB DYLAN  MAC MILLER  METALLICA  MUDCRUTCH  TOM PETTY  \
# aahetfield          0           0          1          0          0
# aarp                0           0          0          0          0
# ability             0           0          2          0          0
# able                2           0          2          0          0
# aboutand            0           1          0          0          0
#
#             TONY BENNETT
# aahetfield             0
# aarp                   1
# ability                0
# able                   0
# aboutand               0

# %%
# We're going to put the term-document matrix into a new gensim format, from df --> sparse matrix --> gensim corpus
sparse_counts = scipy.sparse.csr_matrix(tdm)
corpus = matutils.Sparse2Corpus(sparse_counts)

#A Gensim corpus is essentially a collection of documents:
#**where each document is represented as a list of (word_index, word_count) tuples.**

#This format is compatible with Gensim's topic modeling algorithms, such as Latent Dirichlet Allocation (LDA).

# %%
# Gensim also requires dictionary of the all terms and their respective location in the term-document matrix
cv = pickle.load(open("cv.pkl", "rb"))
id2word = dict((v, k) for k, v in cv.vocabulary_.items())
#unique id given to each word of dict

# %% [markdown]
# Now that we have the corpus (term-document matrix) and id2word (dictionary of location: term), we need to specify two other parameters - the number of topics and the number of passes. Let's start the number of topics at 2, see if the results make sense, and increase the number from there.

# %%
# Now that we have the corpus (term-document matrix) and id2word (dictionary of location: term),
# we need to specify two other parameters as well - the number of topics and the number of passes
lda = models.LdaModel(corpus=corpus, id2word=id2word, num_topics=2, passes=10)
lda.print_topics()
# Out:
# [(0,
#   '0.013*"dont" + 0.009*"yeah" + 0.008*"just" + 0.007*"im" + 0.006*"know" + 0.006*"petty" + 0.006*"aint" + 0.006*"like" + 0.005*"time" + 0.004*"bennett"'),
#  (1,
#   '0.012*"just" + 0.012*"like" + 0.007*"know" + 0.006*"dont" + 0.006*"band" + 0.006*"think" + 0.006*"metallica" + 0.006*"im" + 0.005*"really" + 0.005*"did"')]

# %% [markdown]
# [(0, '0.015*"topic1_word1" + 0.012*"topic1_word2" + ...'),
#  (1, '0.018*"topic2_word1" + 0.010*"topic2_word2" + ...')]
#  *aisa kuch hota hai*
#
# **Each tuple represents a topic, where the first element is the topic number, and the second element is a string containing the top words and their weights=probabilities for that topic.**

# %%
# LDA for num_topics = 3
lda = models.LdaModel(corpus=corpus, id2word=id2word, num_topics=3, passes=10)
lda.print_topics()

#3 distinct topics: passes=iterations
# Out:
# [(0,
#   '0.021*"dont" + 0.018*"yeah" + 0.012*"im" + 0.012*"know" + 0.011*"aint" + 0.011*"just" + 0.007*"like" + 0.006*"til" + 0.006*"need" + 0.005*"wanna"'),
#  (1,
#   '0.010*"just" + 0.009*"petty" + 0.007*"like" + 0.006*"mr" + 0.006*"bennett" + 0.006*"mudcrutch" + 0.006*"really" + 0.005*"band" + 0.005*"dont" + 0.005*"time"'),
#  (2,
#   '0.012*"like" + 0.010*"just" + 0.007*"metallica" + 0.007*"know" + 0.007*"band" + 0.006*"dont" + 0.005*"did" + 0.005*"james" + 0.005*"im" + 0.005*"lot"')]

# %%
# LDA for num_topics = 4
lda = models.LdaModel(corpus=corpus, id2word=id2word, num_topics=4, passes=10)
lda.print_topics()
# Out:
# [(0,
#   '0.012*"like" + 0.010*"just" + 0.009*"band" + 0.006*"dont" + 0.006*"metallica" + 0.006*"petty" + 0.006*"know" + 0.005*"im" + 0.005*"time" + 0.005*"did"'),
#  (1,
#   '0.018*"just" + 0.011*"really" + 0.009*"like" + 0.008*"think" + 0.007*"album" + 0.007*"dont" + 0.007*"know" + 0.006*"good" + 0.006*"im" + 0.005*"thats"'),
#  (2,
#   '0.013*"bennett" + 0.013*"mr" + 0.004*"bennetts" + 0.004*"new" + 0.004*"life" + 0.004*"later" + 0.003*"time" + 0.003*"career" + 0.003*"songs" + 0.003*"singer"'),
#  (3,
#   '0.024*"dont" + 0.020*"yeah" + 0.013*"im" + 0.013*"know" + 0.013*"aint" + 0.012*"just" + 0.007*"like" + 0.007*"til" + 0.007*"need" + 0.005*"wanna"')]

# %% [markdown]
# These topics aren't looking too great. We've tried modifying our parameters. Let's try modifying our terms list as well.

# %% [markdown]
# ## Topic Modeling - Attempt #2 (Nouns Only)

# %% [markdown]
# One popular trick is to look only at terms that are from one part of speech (only nouns, only adjectives, etc.). Check out the UPenn tag set: https://www.ling.upenn.edu/courses/Fall_2003/ling001/penn_treebank_pos.html.

# %%
# Let's create a function to pull out nouns from a string of text
from nltk import word_tokenize, pos_tag

def nouns(text):
    '''Given a string of text, tokenize the text and pull out only the nouns.'''
    is_noun = lambda pos: pos[:2] == 'NN'
    tokenized = word_tokenize(text)
    all_nouns = [word for (word, pos) in pos_tag(tokenized) if is_noun(pos)]
    return ' '.join(all_nouns)

# %%
# Read in the cleaned data, before the CountVectorizer step
data_clean = pd.read_pickle('data_clean.pkl')
data_clean
# Out:
#                                                      transcript
# BOB DYLAN      slane castle and hot press two of the endurin...
# MAC MILLER     mac millers swimming album tracklist come bac...
# METALLICA      even when metallicas quiet they manage to mak...
# MUDCRUTCH      at the dawn of the a young florida band had p...
# TOM PETTY      by bud scoppatom petty jeff lynne got to know...
# TONY BENNETT   from his initial success as a jazzy crooner t...

# %%
import nltk
nltk.download('averaged_perceptron_tagger')
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
# Apply the nouns function to the transcripts to filter only on nouns
data_nouns = pd.DataFrame(data_clean['transcript'].apply(nouns))
data_nouns
# Out:
#                                                      transcript
# BOB DYLAN     slane castle press institutions modem culture ...
# MAC MILLER    mac millers tracklist earth feelings use perfe...
# METALLICA     metallicas noiseon morning middle respite band...
# MUDCRUTCH     dawn florida band dreams anyone bassist petty ...
# TOM PETTY     scoppatom petty jeff lynne manner guitars stru...
# TONY BENNETT  success jazzy crooner duets career longevity c...

# %%
# Create a new document-term matrix using only nouns
from sklearn.feature_extraction import text
from sklearn.feature_extraction.text import CountVectorizer

# Re-add the additional stop words since we are recreating the document-term matrix
add_stop_words = ['like', 'im', 'know', 'just', 'dont', 'thats', 'right', 'people',
                  'youre', 'got', 'gonna', 'time', 'think', 'yeah', 'said']
stop_words = list(text.ENGLISH_STOP_WORDS.union(add_stop_words))

# Recreate a document-term matrix with only nouns
cvn = CountVectorizer(stop_words=stop_words)
data_cvn = cvn.fit_transform(data_nouns.transcript)
data_dtmn = pd.DataFrame(data_cvn.toarray(), columns=cvn.get_feature_names_out())
#This line converts the document-term matrix (data_cvn) into a DataFrame (data_dtmn)
#The .toarray() method converts the sparse matrix into a dense array,
#and cvn.get_feature_names_out() retrieves the feature names (nouns) used as column labels.
data_dtmn.index = data_nouns.index
data_dtmn
# Out:
#               ability  aboutand  aboutpetty  aboutrunnin  accent  acceptance  \
# BOB DYLAN           0         0           0            0       0           0
# MAC MILLER          0         1           0            1       0           0
# METALLICA           2         0           0            0       1           0
# MUDCRUTCH           0         0           1            0       0           1
# TOM PETTY           0         0           0            0       0           0
# TONY BENNETT        0         0           0            0       0           0
#
#               access  accident  accidents  accomplishments  ...  youd  \
# BOB DYLAN          0         0          0                0  ...     1
# MAC MILLER         0         0          0                0  ...     0
# METALLICA          1         2          1                0  ...     1
# MUDCRUTCH          0         0          0                0  ...     0
# TOM PETTY          0         0          0                1  ...     0
# ...

# %%
# Create the gensim corpus
corpusn = matutils.Sparse2Corpus(scipy.sparse.csr_matrix(data_dtmn.transpose()))

# Create the vocabulary dictionary
id2wordn = dict((v, k) for k, v in cvn.vocabulary_.items())

# %%
# Let's start with 2 topics
ldan = models.LdaModel(corpus=corpusn, num_topics=2, id2word=id2wordn, passes=10)
ldan.print_topics()
# Out:
# [(0,
#   '0.014*"band" + 0.008*"metallica" + 0.007*"lot" + 0.007*"james" + 0.007*"music" + 0.006*"bennett" + 0.006*"mudcrutch" + 0.005*"day" + 0.005*"song" + 0.005*"years"'),
#  (1,
#   '0.008*"aint" + 0.007*"way" + 0.006*"record" + 0.006*"life" + 0.005*"album" + 0.005*"song" + 0.005*"songs" + 0.005*"lot" + 0.004*"records" + 0.004*"shit"')]

# %%
# Let's try topics = 3
ldan = models.LdaModel(corpus=corpusn, num_topics=3, id2word=id2wordn, passes=10)
ldan.print_topics()
# Out:
# [(0,
#   '0.012*"mudcrutch" + 0.012*"band" + 0.007*"music" + 0.007*"leadon" + 0.006*"song" + 0.006*"songs" + 0.006*"records" + 0.006*"record" + 0.006*"years" + 0.005*"petty"'),
#  (1,
#   '0.016*"band" + 0.014*"metallica" + 0.012*"james" + 0.011*"lot" + 0.008*"music" + 0.008*"lars" + 0.006*"jason" + 0.006*"day" + 0.005*"metal" + 0.005*"bands"'),
#  (2,
#   '0.009*"bennett" + 0.009*"aint" + 0.007*"life" + 0.006*"album" + 0.006*"mr" + 0.005*"way" + 0.005*"song" + 0.005*"songs" + 0.005*"world" + 0.005*"record"')]

# %%
# Let's try 4 topics
ldan = models.LdaModel(corpus=corpusn, num_topics=4, id2word=id2wordn, passes=10)
ldan.print_topics()
# Out:
# [(0,
#   '0.010*"aint" + 0.010*"band" + 0.009*"mudcrutch" + 0.007*"album" + 0.007*"way" + 0.006*"song" + 0.006*"lot" + 0.005*"life" + 0.005*"record" + 0.005*"leadon"'),
#  (1,
#   '0.021*"bennett" + 0.012*"mr" + 0.007*"life" + 0.007*"bennetts" + 0.006*"singer" + 0.006*"career" + 0.005*"music" + 0.005*"songs" + 0.005*"year" + 0.004*"york"'),
#  (2,
#   '0.018*"band" + 0.016*"metallica" + 0.013*"james" + 0.012*"lot" + 0.009*"music" + 0.008*"lars" + 0.007*"jason" + 0.006*"day" + 0.005*"bands" + 0.005*"metal"'),
#  (3,
#   '0.009*"music" + 0.009*"records" + 0.008*"record" + 0.007*"songs" + 0.006*"room" + 0.006*"family" + 0.005*"song" + 0.005*"way" + 0.005*"years" + 0.004*"life"')]

# %% [markdown]
# ## Topic Modeling - Attempt #3 (Nouns and Adjectives)

# %%
# Let's create a function to pull out nouns from a string of text
def nouns_adj(text):
    '''Given a string of text, tokenize the text and pull out only the nouns and adjectives.'''
    is_noun_adj = lambda pos: pos[:2] == 'NN' or pos[:2] == 'JJ'
    tokenized = word_tokenize(text)
    nouns_adj = [word for (word, pos) in pos_tag(tokenized) if is_noun_adj(pos)]
    return ' '.join(nouns_adj)

# %%
# Apply the nouns function to the transcripts to filter only on nouns
data_nouns_adj = pd.DataFrame(data_clean.transcript.apply(nouns_adj))
data_nouns_adj
# Out:
#                                                      transcript
# BOB DYLAN     slane castle hot press institutions modem iris...
# MAC MILLER    mac millers album tracklist earth feelings use...
# METALLICA     metallicas noiseon midjanuary morning middle l...
# MUDCRUTCH     dawn young florida band plausible dreams big b...
# TOM PETTY     bud scoppatom petty jeff lynne other tradition...
# TONY BENNETT  initial success jazzy crooner duets career rem...

# %%
# Create a new document-term matrix using only nouns and adjectives, also remove common words with max_df
cvna = CountVectorizer(stop_words=stop_words, max_df=.8)
data_cvna = cvna.fit_transform(data_nouns_adj.transcript)
data_dtmna = pd.DataFrame(data_cvna.toarray(), columns=cvna.get_feature_names_out())
data_dtmna.index = data_nouns_adj.index
data_dtmna
# Out:
#               ability  able  aboutand  aboutpetty  aboutrunnin  abstract  \
# BOB DYLAN           0     2         0           0            0         0
# MAC MILLER          0     0         1           0            1         0
# METALLICA           2     2         0           0            0         1
# MUDCRUTCH           0     0         0           1            0         0
# TOM PETTY           0     0         0           0            0         0
# TONY BENNETT        0     0         0           0            0         0
#
#               abusedhammett  accent  acceptance  access  ...  young  younger  \
# BOB DYLAN                 0       0           0       0  ...      3        0
# MAC MILLER                0       0           0       0  ...      2        0
# METALLICA                 1       1           0       1  ...      0        0
# MUDCRUTCH                 0       0           1       0  ...      2        1
# ...

# %%
# Create the gensim corpus
corpusna = matutils.Sparse2Corpus(scipy.sparse.csr_matrix(data_dtmna.transpose()))

# Create the vocabulary dictionary
id2wordna = dict((v, k) for k, v in cvna.vocabulary_.items())

# %%
# Let's start with 2 topics
ldana = models.LdaModel(corpus=corpusna, num_topics=2, id2word=id2wordna, passes=10)
ldana.print_topics()
# Out:
# [(0,
#   '0.010*"petty" + 0.009*"mudcrutch" + 0.006*"tom" + 0.005*"leadon" + 0.004*"gainesville" + 0.003*"room" + 0.003*"studio" + 0.003*"tench" + 0.003*"guitar" + 0.002*"family"'),
#  (1,
#   '0.007*"metallica" + 0.005*"james" + 0.005*"aint" + 0.005*"bennett" + 0.004*"mr" + 0.003*"lars" + 0.003*"shit" + 0.003*"bad" + 0.003*"guy" + 0.003*"jason"')]

# %%
# Let's try 3 topics
ldana = models.LdaModel(corpus=corpusna, num_topics=3, id2word=id2wordna, passes=10)
ldana.print_topics()
# Out:
# [(0,
#   '0.014*"aint" + 0.007*"til" + 0.006*"shit" + 0.006*"jet" + 0.006*"gettin" + 0.004*"ta" + 0.004*"need" + 0.004*"nothin" + 0.003*"high" + 0.003*"wall"'),
#  (1,
#   '0.012*"metallica" + 0.009*"james" + 0.006*"lars" + 0.005*"jason" + 0.005*"guy" + 0.004*"hes" + 0.004*"metal" + 0.004*"bad" + 0.004*"kind" + 0.003*"stuff"'),
#  (2,
#   '0.009*"petty" + 0.009*"bennett" + 0.008*"mudcrutch" + 0.007*"mr" + 0.005*"tom" + 0.004*"leadon" + 0.004*"gainesville" + 0.004*"singer" + 0.003*"bennetts" + 0.003*"american"')]

# %%
# Let's try 4 topics
ldana = models.LdaModel(corpus=corpusna, num_topics=4, id2word=id2wordna, passes=10)
ldana.print_topics()
# Out:
# [(0,
#   '0.007*"wilburys" + 0.006*"heartbreakers" + 0.004*"hes" + 0.004*"hard" + 0.004*"guy" + 0.004*"jeff" + 0.004*"stuff" + 0.004*"studio" + 0.004*"theyre" + 0.004*"hit"'),
#  (1,
#   '0.000*"bennett" + 0.000*"petty" + 0.000*"metallica" + 0.000*"mr" + 0.000*"mudcrutch" + 0.000*"james" + 0.000*"singer" + 0.000*"aint" + 0.000*"family" + 0.000*"shit"'),
#  (2,
#   '0.011*"aint" + 0.010*"bennett" + 0.008*"mr" + 0.005*"til" + 0.005*"shit" + 0.004*"gettin" + 0.004*"jet" + 0.004*"high" + 0.004*"bennetts" + 0.003*"ta"'),
#  (3,
#   '0.010*"metallica" + 0.008*"james" + 0.007*"petty" + 0.007*"mudcrutch" + 0.005*"lars" + 0.004*"tom" + 0.004*"jason" + 0.004*"leadon" + 0.004*"hes" + 0.003*"guy"')]

# %% [markdown]
# ## Identify Topics in Each Document

# %% [markdown]
# Out of the 9 topic models we looked at, the nouns and adjectives, 4 topic one made the most sense. So let's pull that down here and run it through some more iterations to get more fine-tuned topics.

# %%
# Our final LDA model (for now)
ldana = models.LdaModel(corpus=corpusna, num_topics=4, id2word=id2wordna, passes=80)
ldana.print_topics()
# Out:
# [(0,
#   '0.014*"bennett" + 0.012*"mr" + 0.005*"bennetts" + 0.004*"wilburys" + 0.004*"american" + 0.004*"singer" + 0.004*"career" + 0.004*"heartbreakers" + 0.003*"single" + 0.003*"york"'),
#  (1,
#   '0.006*"room" + 0.005*"family" + 0.004*"real" + 0.004*"studio" + 0.004*"hes" + 0.004*"thatdylan" + 0.004*"clancy" + 0.004*"irish" + 0.004*"royal" + 0.003*"sound"'),
#  (2,
#   '0.010*"metallica" + 0.008*"james" + 0.008*"aint" + 0.005*"lars" + 0.005*"shit" + 0.004*"bad" + 0.004*"jason" + 0.004*"fuck" + 0.004*"til" + 0.003*"jet"'),
#  (3,
#   '0.018*"petty" + 0.017*"mudcrutch" + 0.010*"tom" + 0.009*"leadon" + 0.008*"gainesville" + 0.005*"tench" + 0.004*"guitar" + 0.004*"campbell" + 0.004*"mike" + 0.004*"heartbreakers"')]

# %% [markdown]
# ```
# # This is formatted as code
# ```
#
# These four topics look pretty decent. Let's settle on these for now.
# * Topic 0: mom, parents
# * Topic 1: husband, wife
# * Topic 2: guns
# * Topic 3: profanity

# %%
# Let's take a look at which topics each transcript contains
corpus_transformed = ldana[corpusna]
list(zip([a for [(a,b)] in corpus_transformed], data_dtmna.index))
# Out:
# [(1, 'BOB DYLAN'),
#  (2, 'MAC MILLER'),
#  (2, 'METALLICA'),
#  (3, 'MUDCRUTCH'),
#  (0, 'TOM PETTY'),
#  (0, 'TONY BENNETT')]

# %% [markdown]
# For a first pass of LDA, these kind of make sense to me, so we'll call it a day for now.
# * Topic 0: mom, parents [Tom,Tony]
# * Topic 1: husband, wife [Bob]
# * Topic 2: guns [Mac, Metallica]
# * Topic 3: profanity[Mudcrutch]

# %% [markdown]
# ### Assignment:
# 1. Try further modifying the parameters of the topic models above and see if you can get better topics.
# 2. Create a new topic model that includes terms from a different [part of speech](https://www.ling.upenn.edu/courses/Fall_2003/ling001/penn_treebank_pos.html) and see if you can get better topics.

# %%
# Let's take a look at which topics each transcript contains
corpus_transformed = ldana[corpusna]
topics_and_indices = []
for doc_topics in corpus_transformed:
    topic_index, _ = max(doc_topics, key=lambda x: x[1])
    topics_and_indices.append(topic_index)

# Now, zip the topics with the document indices
result = list(zip(topics_and_indices, data_dtmna.index))

# Print the result
print(result)
# Out:
# [(1, 'BOB DYLAN'), (2, 'MAC MILLER'), (2, 'METALLICA'), (3, 'MUDCRUTCH'), (0, 'TOM PETTY'), (0, 'TONY BENNETT')]

# %%
ldana = models.LdaModel(corpus=corpusna, num_topics=6, id2word=id2wordna, passes=20)
ldana.print_topics()
# Out:
# [(0,
#   '0.000*"metallica" + 0.000*"aint" + 0.000*"james" + 0.000*"mr" + 0.000*"bennett" + 0.000*"shit" + 0.000*"family" + 0.000*"hes" + 0.000*"lars" + 0.000*"guy"'),
#  (1,
#   '0.018*"aint" + 0.008*"til" + 0.008*"shit" + 0.007*"jet" + 0.007*"gettin" + 0.006*"ta" + 0.005*"need" + 0.005*"nothin" + 0.004*"high" + 0.004*"wall"'),
#  (2,
#   '0.000*"metallica" + 0.000*"james" + 0.000*"aint" + 0.000*"shit" + 0.000*"lars" + 0.000*"petty" + 0.000*"bad" + 0.000*"guy" + 0.000*"bennett" + 0.000*"fuck"'),
#  (3,
#   '0.016*"metallica" + 0.013*"james" + 0.008*"lars" + 0.007*"jason" + 0.005*"metal" + 0.005*"bad" + 0.005*"guy" + 0.004*"kind" + 0.004*"hes" + 0.004*"fans"'),
#  (4,
#   '0.015*"petty" + 0.014*"mudcrutch" + 0.008*"tom" + 0.008*"leadon" + 0.006*"gainesville" + 0.005*"room" + 0.004*"guitar" + 0.004*"tench" + 0.004*"studio" + 0.003*"family"'),
#  (5,
# ...

# %%
# Let's take a look at which topics each transcript contains
corpus_transformed = ldana[corpusna]
topics_and_indices = []
for doc_topics in corpus_transformed:
    topic_index, _ = max(doc_topics, key=lambda x: x[1])
    topics_and_indices.append(topic_index)

# Now, zip the topics with the document indices
result = list(zip(topics_and_indices, data_dtmna.index))

# Print the result
print(result)
# Out:
# [(4, 'BOB DYLAN'), (1, 'MAC MILLER'), (3, 'METALLICA'), (4, 'MUDCRUTCH'), (5, 'TOM PETTY'), (5, 'TONY BENNETT')]

# %%
def nouns_adj_verbs(text):
    '''Given a string of text, tokenize the text and pull out only the nouns, adjectives, and verbs.'''
    is_noun_adj_verb = lambda pos: pos[:2] == 'NN' or pos[:2] == 'JJ' or pos[:2] == 'VB'
    tokenized = word_tokenize(text)
    nouns_adj_verbs = [word for (word, pos) in pos_tag(tokenized) if is_noun_adj_verb(pos)]
    return ' '.join(nouns_adj_verbs)

# %%
# Apply the new function to the transcripts to filter only on nouns, adjectives, and verbs
data_nouns_adj_verbs = pd.DataFrame(data_clean.transcript.apply(nouns_adj_verbs))

# Create a new document-term matrix using nouns, adjectives, and verbs
cvnav = CountVectorizer(stop_words=stop_words)
data_cvnav = cvnav.fit_transform(data_nouns_adj_verbs.transcript)
data_dtmnav = pd.DataFrame(data_cvnav.toarray(), columns=cvnav.get_feature_names_out())
data_dtmnav.index = data_nouns_adj_verbs.index

data_dtmnav
# Out:
#               aahetfield  ability  able  aboutand  aboutpetty  aboutrunnin  \
# BOB DYLAN              0        0     2         0           0            0
# MAC MILLER             0        0     0         1           0            1
# METALLICA              1        2     2         0           0            0
# MUDCRUTCH              0        0     0         0           1            0
# TOM PETTY              0        0     0         0           0            0
# TONY BENNETT           0        0     0         0           0            0
#
#               abstract  abused  abusedhammett  accent  ...  young  younger  \
# BOB DYLAN            0       0              0       0  ...      3        0
# MAC MILLER           0       0              0       0  ...      2        0
# METALLICA            1       2              1       1  ...      0        0
# MUDCRUTCH            0       0              0       0  ...      2        1
# ...

# %%
# Create the gensim corpus
corpusnav = matutils.Sparse2Corpus(scipy.sparse.csr_matrix(data_dtmnav.transpose()))

# Create the vocabulary dictionary
id2wordnav = dict((v, k) for k, v in cvnav.vocabulary_.items())

# %%
# Let's start with 2 topics
ldanav = models.LdaModel(corpus=corpusnav, num_topics=2, id2word=id2wordnav, passes=10)
ldanav.print_topics()
# Out:
# [(0,
#   '0.007*"band" + 0.005*"did" + 0.005*"metallica" + 0.004*"lot" + 0.004*"record" + 0.004*"music" + 0.004*"good" + 0.004*"petty" + 0.004*"song" + 0.004*"album"'),
#  (1,
#   '0.011*"aint" + 0.005*"need" + 0.004*"gettin" + 0.004*"til" + 0.004*"come" + 0.004*"shit" + 0.003*"wan" + 0.003*"way" + 0.003*"tell" + 0.003*"jet"')]

# %%
# Let's start with 3 topics
ldanav = models.LdaModel(corpus=corpusnav, num_topics=3, id2word=id2wordnav, passes=10)
ldanav.print_topics()
# Out:
# [(0,
#   '0.009*"band" + 0.006*"metallica" + 0.006*"did" + 0.005*"lot" + 0.005*"record" + 0.005*"petty" + 0.005*"good" + 0.004*"music" + 0.004*"james" + 0.004*"album"'),
#  (1,
#   '0.012*"bennett" + 0.011*"mr" + 0.004*"bennetts" + 0.004*"new" + 0.003*"life" + 0.003*"career" + 0.003*"songs" + 0.003*"singer" + 0.003*"american" + 0.003*"music"'),
#  (2,
#   '0.013*"aint" + 0.006*"need" + 0.005*"gettin" + 0.005*"til" + 0.005*"come" + 0.005*"shit" + 0.004*"wan" + 0.004*"way" + 0.004*"jet" + 0.004*"tell"')]

# %%
# Let's start with 4 topics
ldanav = models.LdaModel(corpus=corpusnav, num_topics=4, id2word=id2wordnav, passes=10)
ldanav.print_topics()
# Out:
# [(0,
#   '0.015*"petty" + 0.013*"mudcrutch" + 0.009*"band" + 0.007*"tom" + 0.007*"leadon" + 0.006*"says" + 0.005*"gainesville" + 0.003*"play" + 0.003*"admits" + 0.003*"tench"'),
#  (1,
#   '0.008*"metallica" + 0.007*"band" + 0.006*"james" + 0.006*"did" + 0.006*"bennett" + 0.005*"mr" + 0.005*"lot" + 0.005*"music" + 0.004*"lars" + 0.003*"going"'),
#  (2,
#   '0.008*"record" + 0.008*"good" + 0.006*"ive" + 0.006*"album" + 0.005*"play" + 0.005*"songs" + 0.005*"song" + 0.005*"didnt" + 0.005*"used" + 0.004*"great"'),
#  (3,
#   '0.015*"aint" + 0.007*"need" + 0.006*"gettin" + 0.006*"til" + 0.005*"come" + 0.005*"shit" + 0.004*"wan" + 0.004*"way" + 0.004*"tell" + 0.004*"jet"')]

# %%
# Our final LDA model (for now)
ldana = models.LdaModel(corpus=corpusnav, num_topics=4, id2word=id2wordnav, passes=80)
ldana.print_topics()
# Out:
# [(0,
#   '0.010*"petty" + 0.009*"mudcrutch" + 0.007*"band" + 0.006*"record" + 0.005*"tom" + 0.005*"leadon" + 0.005*"didnt" + 0.005*"play" + 0.005*"good" + 0.004*"used"'),
#  (1,
#   '0.011*"aint" + 0.006*"good" + 0.005*"need" + 0.005*"gon" + 0.005*"come" + 0.005*"gettin" + 0.005*"album" + 0.004*"til" + 0.004*"little" + 0.004*"way"'),
#  (2,
#   '0.010*"metallica" + 0.009*"band" + 0.008*"james" + 0.007*"did" + 0.006*"lot" + 0.005*"lars" + 0.005*"music" + 0.005*"going" + 0.004*"fucking" + 0.004*"hetfield"'),
#  (3,
#   '0.014*"bennett" + 0.013*"mr" + 0.005*"bennetts" + 0.004*"new" + 0.004*"life" + 0.004*"career" + 0.003*"songs" + 0.003*"american" + 0.003*"singer" + 0.003*"year"')]

# %%
corpus_transformed_v = ldana[corpusnav]
topics_and_indices = []
for doc_topics in corpus_transformed_v:
    topic_index, _ = max(doc_topics, key=lambda x: x[1])
    topics_and_indices.append(topic_index)

# Now, zip the topics with the document indices
result = list(zip(topics_and_indices, data_dtmnav.index))

# Print the result
print(result)
# Out:
# [(0, 'BOB DYLAN'), (1, 'MAC MILLER'), (2, 'METALLICA'), (0, 'MUDCRUTCH'), (1, 'TOM PETTY'), (3, 'TONY BENNETT')]
